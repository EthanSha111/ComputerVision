# %% [markdown]
# # CSCI-UA 0480-042 Computer Vision
# ## Homework 4

# %% [markdown]
# Enter your name and NetID below.
#
# #### Name: Ethan Sha
# #### NetID: ys4323

# %% [markdown]
# The main goals of this assignment include:
#
# 1. Giving an introduction to DETR
# 2. Visualizing attention masks at different layers of te transformer
# 3. Generating bounding boxes for a test image
# 4. Visualizing panoptic segments identified by the model
#
#
# There are (**4 questions in total**). Please give your answers in the space provided. In most of the questions, you will be asked to complete a code snippet. You can quickly navigate to those questions by searching (Ctrl/Cmd-F) for `TODO:`. For questions requiring a markdown answer, navigate to them by searching `Answer`.

# %% [markdown]
# # 1. Introduction to DETR

# %% [markdown]
# DETR, or "DEtection TRansformers," is a novel object detection framework that leverages transformer architectures for the task of object detection in computer vision. It was introduced in the paper titled "End-to-End Object Detection with Transformers," presented at the European Conference on Computer Vision (ECCV) in 2020.
#
# Key features of DETR include:
#
# 1. **End-to-End Framework:** DETR eliminates the need for separate region proposal networks and subsequent refinement stages. It directly predicts the set of objects and their corresponding bounding boxes in a single forward pass.
#
# 2. **Set Prediction:** Instead of predicting a fixed number of bounding box proposals, DETR treats object detection as a set prediction problem. The transformer outputs a fixed number of object queries, and a learnable permutation is applied to match these queries with the ground truth objects.
#
# 3. **Attention Mechanisms:** DETR utilizes self-attention mechanisms within the transformer architecture to capture global context information, allowing the model to consider relationships between different parts of the image.
#
# 4. **Positional Encodings:** As transformers do not inherently understand the spatial information of input sequences, DETR incorporates positional encodings to provide information about the absolute and relative positions of objects in the image.

# %%
import math

from PIL import Image
import requests
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format = 'retina'

from IPython.display import display, clear_output

import torch
from torch import nn
import torchvision
import torchvision.transforms as T

torch.set_grad_enabled(False)

# %%
# COCO classes
CLASSES = [
    'N/A', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A',
    'stop sign', 'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse',
    'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack',
    'umbrella', 'N/A', 'N/A', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis',
    'snowboard', 'sports ball', 'kite', 'baseball bat', 'baseball glove',
    'skateboard', 'surfboard', 'tennis racket', 'bottle', 'N/A', 'wine glass',
    'cup', 'fork', 'knife', 'spoon', 'bowl', 'banana', 'apple', 'sandwich',
    'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', 'donut', 'cake',
    'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table', 'N/A',
    'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard',
    'cell phone', 'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A',
    'book', 'clock', 'vase', 'scissors', 'teddy bear', 'hair drier',
    'toothbrush'
]

# colors for visualization
COLORS = [[0.000, 0.447, 0.741], [0.850, 0.325, 0.098], [0.929, 0.694, 0.125],
          [0.494, 0.184, 0.556], [0.466, 0.674, 0.188], [0.301, 0.745, 0.933]]

# %%
# for output bounding box post-processing
def box_cxcywh_to_xyxy(x):
    x_c, y_c, w, h = x.unbind(1)
    b = [(x_c - 0.5 * w), (y_c - 0.5 * h),
         (x_c + 0.5 * w), (y_c + 0.5 * h)]
    return torch.stack(b, dim=1)

def rescale_bboxes(out_bbox, size):
    img_w, img_h = size
    b = box_cxcywh_to_xyxy(out_bbox)
    b = b * torch.tensor([img_w, img_h, img_w, img_h], dtype=torch.float32)
    return b

# %%
def plot_results(pil_img, prob, boxes):
    plt.figure(figsize=(16,10))
    plt.imshow(pil_img)
    ax = plt.gca()
    colors = COLORS * 100
    for p, (xmin, ymin, xmax, ymax), c in zip(prob, boxes.tolist(), colors):
        ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                                   fill=False, color=c, linewidth=3))
        cl = p.argmax()
        text = f'{CLASSES[cl]}: {p[cl]:0.2f}'
        ax.text(xmin, ymin, text, fontsize=15,
                bbox=dict(facecolor='yellow', alpha=0.5))
    plt.axis('off')
    plt.show()

# %% [markdown]
# ## 1.1 Load the pretrained resnet50 model via torch.hub [10%]

# %% [markdown]
# #### You first need to set the torch.hub download path to a local dir so that it doesn't download the model in the cache

# %%
local_path = "detr_model"
torch.hub.set_dir(local_path)

# %% [markdown]
# #### Next, load the mode `detr_resnet50` under `facebookresearch/detr` using torch.hub.load

# %%
# TODO: Load the detr_resnet50 pretrained model

detr_model = torch.hub.load('facebookresearch/detr', 'detr_resnet50', pretrained=True)

# Set the model to evaluation mode
detr_model.eval()
# Out:
# Using cache found in detr_model/facebookresearch_detr_main
# /opt/conda/envs/csciua-0480042-fall/lib/python3.8/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /opt/conda/envs/csciua-0480042-fall/lib/python3.8/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# DETR(
#   (transformer): Transformer(
#     (encoder): TransformerEncoder(
#       (layers): ModuleList(
#         (0-5): 6 x TransformerEncoderLayer(
#           (self_attn): MultiheadAttention(
# ...

# %%
num_encoder_layers = 6
num_decoder_layers = 6


num_layers = (num_encoder_layers, num_decoder_layers)

# %% [markdown]
# ## 1.2 Generating bounding boxes

# %% [markdown]
# #### Download an image of your choice from https://cocodataset.org/#explore [10%]

# %%
# TODO: Load image
img_path = "cat.jpg"
im = Image.open(img_path)

# %% [markdown]
# #### Transform image and generate output

# %%
# standard PyTorch mean-std input image normalization
transform = T.Compose([
    T.Resize(800),
    T.ToTensor(),
    T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    
])

# TODO: transform the image using the transform specified above
img = transform(im).unsqueeze(0) 


# TODO: propagate through the model
outputs = detr_model(img)

# keep only predictions with 0.7+ confidence
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.9

# convert boxes from [0; 1] to image scales
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)

plot_results(im, probas[keep], bboxes_scaled)

# %% [markdown]
# # 2. Visualizing Attention Weights

# %% [markdown]
# ## 2.1. Using the code snippet below as a guide, visualize the encoder and decoder attention weights for each layer of the transformer [25%]

# %% [markdown]
# #### Use lists to store the outputs via up-values
#
# ```
# conv_features, enc_attn_weights, dec_attn_weights = [], [], []
#
# hooks = [
#     model.backbone[-2].register_forward_hook(
#         lambda self, input, output: conv_features.append(output)
#     ),
#     model.transformer.encoder.layers[0].self_attn.register_forward_hook(
#         lambda self, input, output: enc_attn_weights.append(output[1])
#     ),
#     model.transformer.decoder.layers[0].multihead_attn.register_forward_hook(
#         lambda self, input, output: dec_attn_weights.append(output[1])
#     ),
# ]
# ```
#
# #### Propagate through the model
#
# ```
# outputs = model(img)
#
# for hook in hooks:
#     hook.remove()
# ```
#
# ### `Note:` Remember to pop the first element from each list before plotting

# %%
# Use lists to store the outputs via up-values
conv_features, enc_attn_weights, dec_attn_weights = [], [], []

# Set up hooks
hooks = [
    detr_model.backbone[-2].register_forward_hook(
        lambda self, input, output: conv_features.append(output)
    ),
    detr_model.transformer.encoder.layers[0].self_attn.register_forward_hook(
        lambda self, input, output: enc_attn_weights.append(output[1])
    ),
    detr_model.transformer.decoder.layers[0].multihead_attn.register_forward_hook(
        lambda self, input, output: dec_attn_weights.append(output[1])
    )
]

# Propagate through the model
outputs = detr_model(img)

# Remove hooks
for hook in hooks:
    hook.remove()

# TODO: Pop the elements
conv_features = conv_features[0]
enc_attn_weights = enc_attn_weights[0]
dec_attn_weights = dec_attn_weights[0]



# Now get the shape of this tensor
h, w = conv_features['0'].tensors.shape[-2:]


fig, axs = plt.subplots(ncols=len(bboxes_scaled), nrows=2, figsize=(22, 7))
for idx, ax_i, (xmin, ymin, xmax, ymax) in zip(keep.nonzero(), axs.T, bboxes_scaled):
    ax = ax_i[0]
    ax.imshow(enc_attn_weights[0][idx.item()].view(h, w))
    ax.axis('off')
    ax.set_title(f'query id: {idx.item()}')
    ax = ax_i[1]
    ax.imshow(im)
    ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                               fill=False, color='blue', linewidth=3))
    ax.axis('off')
    ax.set_title(CLASSES[probas[idx].argmax()])
fig.tight_layout()

# %% [markdown]
# # 2.2. What do you observe? [10%]
#
# Write in your own words

# %% [markdown]
# `Answer`
#
# The top row displays attention heatmaps for different query IDs. These maps show which regions of the input image the model is focusing on when predicting a particular object class. Brighter areas indicate higher attention, suggesting these regions have more influence on the model's output for that query.
#
# The bottom row shows the original image with bounding boxes around the detected objects. These boxes are presumably drawn based on the model's predictions, with the labels indicating the class of the detected object, correctly detecting remote, bottle, tv, laptop, bed and cat.
#
# By comparing the attention maps with the bounding boxes, we can infer how well the model's attention mechanism aligns with the spatial location of the objects. From what we learn from class, the attention heatmap should be concentrated on or around the object that corresponds to the query ID, but the result of visualization doesn't indicate a very good match between the attention area and the actual object location for most of the cases.
#
# In summary, these visualizations provide insight into the interpretability of the model's predictions. They can be particularly informative in understanding the internal workings of the DETR model.

# %% [markdown]
# # 3. Using a different backbone

# %% [markdown]
# There is another pre-trained DETR model available with a `resnet101` backbone (`detr_resnet101`)
#
# Similar to the `detr_resnet50` backone you used above, visualize bounding boxes and attention maps for each layer of the encoder and decoder using a `resnet101` backbone

# %% [markdown]
# ### Before downloading resnet101 make sure to clean-up the local_path to not run out of memory
#
# `!rm -r "$local_path""/facebookresearch_detr_main"`
#
# `!rm -r "$local_path""/checkpoints"`

# %% [markdown]
# ## 3.1 Generating Bounding Boxes [5%]

# %%
# Clean-up local_path to prevent running out of memory
# !rm -rf "$local_path/facebookresearch_detr_main"
# !rm -rf "$local_path/checkpoints"

# Download and load the DETR model with a ResNet101 backbone
detr_resnet101 = torch.hub.load('facebookresearch/detr', 'detr_resnet101', pretrained=True)
detr_resnet101.eval()

transformed_img = transform(im).unsqueeze(0)  # Add batch dimension

outputs = detr_resnet101(transformed_img)

# Similar and use the same evaluation
probas = outputs['pred_logits'].softmax(-1)[0, :, :-1]
keep = probas.max(-1).values > 0.9
bboxes_scaled = rescale_bboxes(outputs['pred_boxes'][0, keep], im.size)

plot_results(im, probas[keep], bboxes_scaled)
# Out:
# Downloading: "https://github.com/facebookresearch/detr/zipball/main" to detr_model/main.zip
# Downloading: "https://download.pytorch.org/models/resnet101-63fe2227.pth" to detr_model/checkpoints/resnet101-63fe2227.pth
# 100%|██████████| 171M/171M [00:04<00:00, 41.2MB/s]
# Downloading: "https://dl.fbaipublicfiles.com/detr/detr-r101-2c7b67e5.pth" to detr_model/checkpoints/detr-r101-2c7b67e5.pth
# 100%|██████████| 232M/232M [00:06<00:00, 38.1MB/s]

# %% [markdown]
# ## 3.2 Visualizing Attention Maps [5%]

# %%
# Use lists to store the outputs via up-values
conv_features, enc_attn_weights, dec_attn_weights = [], [], []

# Set up hooks
hooks = [
   detr_resnet101.backbone[-2].register_forward_hook(
        lambda self, input, output: conv_features.append(output)
    ),
   detr_resnet101.transformer.encoder.layers[0].self_attn.register_forward_hook(
        lambda self, input, output: enc_attn_weights.append(output[1])
    ),
    detr_resnet101.transformer.decoder.layers[0].multihead_attn.register_forward_hook(
        lambda self, input, output: dec_attn_weights.append(output[1])
    )
]

# Propagate through the model
outputs = detr_resnet101(img)

# Remove hooks
for hook in hooks:
    hook.remove()

# TODO: Pop the elements
conv_features = conv_features[0]
enc_attn_weights = enc_attn_weights[0]
dec_attn_weights = dec_attn_weights[0]



# Now get the shape of this tensor
h, w = conv_features['0'].tensors.shape[-2:]


fig, axs = plt.subplots(ncols=len(bboxes_scaled), nrows=2, figsize=(22, 7))
for idx, ax_i, (xmin, ymin, xmax, ymax) in zip(keep.nonzero(), axs.T, bboxes_scaled):
    ax = ax_i[0]
    ax.imshow(enc_attn_weights[0][idx.item()].view(h, w))
    ax.axis('off')
    ax.set_title(f'query id: {idx.item()}')
    ax = ax_i[1]
    ax.imshow(im)
    ax.add_patch(plt.Rectangle((xmin, ymin), xmax - xmin, ymax - ymin,
                               fill=False, color='blue', linewidth=3))
    ax.axis('off')
    ax.set_title(CLASSES[probas[idx].argmax()])
fig.tight_layout()

# %% [markdown]
# # 4. What do you observe? How do the visualizations using the 2 different backbones compare? [35%]
#
# Give your insights in a maximum of 100 words

# %% [markdown]
# `Answer`
# The answer starts with the observation of Resnet101 model result:
#
# Similarly as the previous observation, the attention maps for Resnet 101 above the images appear to demonstrate distinct areas of focus, with some squares obviously brighter than others, indicating where the model is concentrating its attention when identifying objects.
#
# In the images below the attention maps, the bounding boxes are drawn around the objects that the model has identified. The labels such as 'remote', 'person', 'cat', 'bed', 'bottle', 'tv', and 'laptop' suggest that the model can also recognize and localize multiple objects within the scene.
#
# The attention maps closely align with the locations of the objects as outlined by the bounding boxes. For instance, the attention map for the 'bottle' query id shows a clear focus where the bottle is actually located in the image.
#
# Now the comparison:
# ResNet101, having more layers, potentially produced more refined attention maps than ResNet50, leading to better localization of objects. As seen from the visualization result, there is a clearer contrast between bright and dark areas for ResNet 101, and the bright areas slighly align better with the bounding boxes than that in ResNet 50.
#
# With more layers, the ResNet101 backbone provided better feature extraction capabilities, which could lead to more accurate object detection, like it even detected the 'person' in the 'TV' which had previously not been correctly detected by ResNet50.
#
# Finally, the increased complexity of ResNet101 led to longer inference times and higher memory usage.
